# %% [markdown]
# # Battle of Neighbourhoods

# %% [markdown]
# ## Review: Distribution Centres
#
# Distribution and efficient supply chain network is the backbone of any retail industry business. It is a principal part, the order processing element, of the entire order fulfilment process. Distribution centres are usually thought of as being demand driven. Distribution centres are the foundation of a supply network, as they allow a single location to stock a vast number of products. Some organizations operate both retail distribution and direct-to-consumer out of a single facility, sharing space, equipment, labour resources, and inventory as applicable. A typical retail distribution network operates with centres set up throughout a commercial market, with each centre serving a number of stores. Large distribution centres for companies such as Wal-Mart serve 50–125 stores. Suppliers ship truckload of products to the distribution centre, which stores the product until needed by the retail location and ships the proper quantity. Since a large retailer might sell tens of thousands of products from thousands of vendors, it would be impossibly inefficient to ship each product directly from each vendor to each store. Many retailers own and run their own distribution networks, while smaller retailers may outsource this function to dedicated logistics firms that coordinate the distribution of products for a number of companies.

# %% [markdown]
# ## Business Problem and Objective
#
# A retail firm seeks to expand its business in NYC.. The objective is therefore, to select the best venue to open up a distribution centre. Although there are many parameters which define a best location, this report will cover the shopping mall distribution frequency using data clustering.

# %% [markdown]
# ## Reason for choosing this project
#
# Since 2016, there has been a significant concern for the oversupply of retail space and failed shopping centres in the world. Brick and mortar centres are replaced by e-commerce businesses. In the current scenario, it thus becomes all the more important to enter into retail business with careful scrutiny and a clear picture of the market.

# %% [markdown]
# ## Data
#
# Wikipedia data and Foursquare API will be used to consolidate data on NYC.

# %% [markdown]
# ## Table of contents
#
# 1. Import Libraries
# 2. Load Foursquare credentials
# 3. City location details
# 4. Searching for shops and cleaning data frame
# 5. Visualize

# %% [markdown]
# ### Import libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

# %% [markdown]
# ### Foursquare credentials

# %%
ClIENT_ID = 'GEQ4LB4254RJRETDQVM5OVPN5Q1DDLOQXCLSDIN1CNGZZA00' # your Foursquare ID
ClIENT_SECRET = 'OSPZF1NUUF15IVPLXAT0OJLXXERHILRVI313MARVI3WWX5BQ' # your Foursquare Secret
VERSION = '20190604'
LIMIT =500
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: GEQ4LB4254RJRETDQVM5OVPN5Q1DDLOQXCLSDIN1CNGZZA00
# Foursquare_Secret:OSPZF1NUUF15IVPLXAT0OJLXXERHILRVI313MARVI3WWX5BQ

# %% [markdown]
# ### City location

# %%
# define the city and get its latitude & longitude 
city = 'New york'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7127281 -74.0060152

# %% [markdown]
# ### Searching for shops and cleaning data frame

# %%
# search for shops
search_query = 'Shop'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=GEQ4LB4254RJRETDQVM5OVPN5Q1DDLOQXCLSDIN1CNGZZA00&client_secret=OSPZF1NUUF15IVPLXAT0OJLXXERHILRVI313MARVI3WWX5BQ&ll=40.7127281,-74.0060152&v=20190604&query=Shop&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...         NaN
# 1  [{'id': '4bf58dd8d48988d128951735', 'name': 'G...         NaN
# 2  [{'id': '4bf58dd8d48988d101951735', 'name': 'T...         NaN
# 3  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...      346065
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  /delivery_provider_seamless_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4               seamless  https://www.seamless.com/menu/melt-shop-fulton...
#
#    hasPerk                        id location.address location.cc  \
# 0    False  52a0a3d411d2a9c50dff1d6e       46 Park Pl          US
# 1    False  4b79a5e8f964a52037082fe3     234 Canal St          US
# 2    False  4bc3a005f8219c74815eb610  119 Chambers St          US
# 3    False  4c88d0d90f3c236a088ef55c    Fulton Street          US
# 4    False  53a7307a498e56d9917d8f32    111 Fulton St          US
#
#   location.city location.country        location.crossStreet  \
# 0      New York    United States               Church Street
# 1      New York    United States               at Centre St.
# 2      New York    United States   btwn Broadway & Church St
# 3      New York    United States                 William St.
# 4      New York    United States  btwn William St & Dutch St
#
#    location.distance                          location.formattedAddress  \
# 0                312  [46 Park Pl (Church Street), New York, NY 1000...
# 1                  3  [234 Canal St (at Centre St.), New York, NY 10...
# 2                356  [119 Chambers St (btwn Broadway & Church St), ...
# 3                367  [Fulton Street (William St.), New York, NY 100...
# 4                330  [111 Fulton St (btwn William St & Dutch St), N...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.7134161580909,...     40.713416
# 1  [{'label': 'display', 'lat': 40.71273261495395...     40.712733
# 2  [{'label': 'display', 'lat': 40.71525006902321...     40.715250
# 3  [{'label': 'display', 'lat': 40.70942474687731...     40.709425
# 4  [{'label': 'display', 'lat': 40.70980014513768...     40.709800
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -74.009610                   NaN               10007             NY
# 1    -74.005978                   NaN               10013             NY
# 2    -74.008625                   NaN               10007             NY
# 3    -74.006087                   NaN               10038             NY
# 4    -74.006677    Financial District               10038             NY
#
#                         name    referralId venuePage.id
# 0          Ray's Barber Shop  v-1561603485     73100413
# 1               NY Gift Shop  v-1561603485          NaN
# 2  Housing Works Thrift Shop  v-1561603485          NaN
# 3          Royal Barber Shop  v-1561603485          NaN
# 4                  Melt Shop  v-1561603485          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                         name              categories          address  cc  \
# 0          Ray's Barber Shop      Salon / Barbershop       46 Park Pl  US
# 1               NY Gift Shop               Gift Shop     234 Canal St  US
# 2  Housing Works Thrift Shop  Thrift / Vintage Store  119 Chambers St  US
# 3          Royal Barber Shop      Salon / Barbershop    Fulton Street  US
# 4                  Melt Shop          Sandwich Place    111 Fulton St  US
#
#        city        country                 crossStreet  distance  \
# 0  New York  United States               Church Street       312
# 1  New York  United States               at Centre St.         3
# 2  New York  United States   btwn Broadway & Church St       356
# 3  New York  United States                 William St.       367
# 4  New York  United States  btwn William St & Dutch St       330
#
#                                     formattedAddress  \
# 0  [46 Park Pl (Church Street), New York, NY 1000...
# 1  [234 Canal St (at Centre St.), New York, NY 10...
# 2  [119 Chambers St (btwn Broadway & Church St), ...
# 3  [Fulton Street (William St.), New York, NY 100...
# 4  [111 Fulton St (btwn William St & Dutch St), N...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.7134161580909,...  40.713416 -74.009610
# 1  [{'label': 'display', 'lat': 40.71273261495395...  40.712733 -74.005978
# 2  [{'label': 'display', 'lat': 40.71525006902321...  40.715250 -74.008625
# 3  [{'label': 'display', 'lat': 40.70942474687731...  40.709425 -74.006087
# 4  [{'label': 'display', 'lat': 40.70980014513768...  40.709800 -74.006677
#
#          neighborhood postalCode state                        id
# 0                 NaN      10007    NY  52a0a3d411d2a9c50dff1d6e
# 1                 NaN      10013    NY  4b79a5e8f964a52037082fe3
# 2                 NaN      10007    NY  4bc3a005f8219c74815eb610
# 3                 NaN      10038    NY  4c88d0d90f3c236a088ef55c
# 4  Financial District      10038    NY  53a7307a498e56d9917d8f32

# %%
# delete unnecessary columns
shop_df= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'formattedAddress',\
                                        'labeledLatLngs', 'id', 'distance', 'postalCode', 'state'], axis=1)
shop_df
# Out:
#                                         name              categories  \
# 0                          Ray's Barber Shop      Salon / Barbershop
# 1                               NY Gift Shop               Gift Shop
# 2                  Housing Works Thrift Shop  Thrift / Vintage Store
# 3                          Royal Barber Shop      Salon / Barbershop
# 4                                  Melt Shop          Sandwich Place
# 5                                 Smoke Shop              Smoke Shop
# 6                         Mary's Coffee Shop             Coffee Shop
# 7                     Potbelly Sandwich Shop          Sandwich Place
# 8                       For Five Coffee Shop             Coffee Shop
# 9   Lux Accessories @ Shop Small Pop-Up Mall           Jewelry Store
# 10                    Potbelly Sandwich Shop          Sandwich Place
# 11                         Dante Coffee Shop             Coffee Shop
# 12          Iron Valley Harley Davidson Shop                    None
# 13                       Stubble Barber Shop      Salon / Barbershop
# 14                           SHoP Architects                  Office
# 15                       Buttercup Bake Shop                  Bakery
# 16                NYC SMOKE SHOP & VAPE SHOP              Smoke Shop
# 17                                      Shop                  Office
# 18                    The Magic Costume Shop       College Classroom
# 19                          Expo Barber Shop      Salon / Barbershop
# 20                          Antonella's Shop      Salon / Barbershop
# 21                               Cinema shop                    None
# 22                       Signorina joli Shop                Boutique
# 23                     millennium smoke shop              Smoke Shop
# 24                                Smoke Shop              Smoke Shop
# 25                     City Hall Barber Shop      Salon / Barbershop
# 26                             The Silk Shop           Women's Store
# 27                               Flower Shop           Deli / Bodega
# 28                       Discount Smoke Shop              Smoke Shop
# 29   Fulton Smoke Shop And Comvenience Store              Smoke Shop
#
#                          address        lat        lng        neighborhood
# 0                     46 Park Pl  40.713416 -74.009610                 NaN
# 1                   234 Canal St  40.712733 -74.005978                 NaN
# 2                119 Chambers St  40.715250 -74.008625                 NaN
# 3                  Fulton Street  40.709425 -74.006087                 NaN
# 4                  111 Fulton St  40.709800 -74.006677  Financial District
# 5                    20 Vesey St  40.711904 -74.010305                 NaN
# 6             25-15 Queens Plz N  40.712786 -74.005944                 NaN
# 7             127 Fulton Street,  40.710139 -74.007363                 NaN
# 8                  1 Liberty Plz  40.709554 -74.010576                 NaN
# 9                            NaN  40.712781 -74.005944                 NaN
# 10                  280 Broadway  40.714480 -74.005842                 NaN
# 11  Tribeca Park , jakarta barat  40.712250 -74.005640                 NaN
# 12                           NaN  40.712957 -74.005941                 NaN
# 13                    1 Platt St  40.707439 -74.005938                 NaN
# 14            233 Broadway Fl 11  40.712409 -74.008512                 NaN
# 15                  200 Broadway  40.710670 -74.009243  Financial District
# 16                    12 John St  40.710170 -74.009383                 NaN
# 17                    11 Park Pl  40.713213 -74.008417                 NaN
# 18                   41 Park Row  40.712463 -74.006728                 NaN
# 19                 90 William St  40.708265 -74.007723                 NaN
# 20                  8 Beekman St  40.711614 -74.006625                 NaN
# 21                           NaN  40.712311 -74.007118                 NaN
# 22                      new york  40.713779 -74.005559                 NaN
# 23                24 Maiden Lane  40.708998 -74.009094                 NaN
# 24                           NaN  40.708969 -74.006231                 NaN
# 25                  111 Worth St  40.715881 -74.003975                 NaN
# 26                 132 Nassau St  40.711117 -74.006896                 NaN
# 27           149 Chambers Street  40.714148 -74.007275                 NaN
# 28                  82 Nassau St  40.709792 -74.007908                 NaN
# 29                  50 Fulton St  40.708336 -74.004557                 NaN

# %% [markdown]
# ### visualize

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(shop_df['lat'], shop_df['lng'], 
                                           shop_df['name'],shop_df['categories'], shop_df['address']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
